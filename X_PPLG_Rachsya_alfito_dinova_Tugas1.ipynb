# %% [markdown]
# <a href="https://colab.research.google.com/github/rachsyaalfitodinova/Cool-GIFs-For-GitHub/blob/main/X_PPLG_Rachsya_alfito_dinova_Tugas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tugas 1 membuat tipe data dan variabel
# Nama kelompok:dosq mistery
# Anggota:
# 1. Rachsya alfito dinova
# 2. Habib Restu Pamungkas
# 3. Muhammad wildan alfajr
# 4. Raditya muhamad qaessar
# 5. Jauza attalah hariyanto
# 6. Radit eka winata

# %%
# %%writefile praktik_variabel.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#       // Deklarasi  Variable dan tipe data
#     string namaBarang = "Laptop       Asus";
#     int jumlah = 2;
#     float harga = 7500000.50;
#     char kategori = 'A';
#     bool tersedia = true;
#
#     //Menampilkan Output ke layar
#     cout << "=== DATA INVENTARIS ===" << endl;
#     cout << "Nama Barang : " << namaBarang << endl;
#     cout << "Kategori    : " << kategori << endl;
#     cout << "Jumlah      : " << jumlah << endl;
#     cout << "Harga       : Rp " << harga << endl;
#     cout << "Tersedia    : " << tersedia <<  " (1 = ya ,0  = tidak )" <<endl;
#     cout << "=======================" << endl;
#
#     return 0;
# }
# Out:
# Overwriting praktik_variabel.cpp

# %%
# !g++ praktik_variabel.cpp -o praktik_variabel
# !./praktik_variabel
# Out:
# === DATA INVENTARIS ===
# Nama Barang : Laptop       Asus
# Kategori    : A
# Jumlah      : 2
# Harga       : Rp 7.5e+06
# Tersedia    : 1 (1 = ya ,0  = tidak )
# ...

# %%
# %%writefile input_data.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#     string namaSiswa;
#     int umur;
#
#
#     cout << "Masukkan Nama (1 Kata) : ";
#     cin >> namaSiswa;
#
#     cout << "Masukkan Umur Anda     : ";
#     cin >> umur;
#
#     cout << "\nHalo " << namaSiswa << ", ternyata umur kamu " << umur << " tahun ya!" << endl;
#     return 0;
# }
# Out:
# Writing input_data.cpp

# %%
# !g++ input_data.cpp -o input_data
# !./input_data
# Out:
# Masukkan Nama (1 Kata) : Alfito
# Masukkan Umur Anda     : 15
#
# Halo Alfito, ternyata umur kamu 15 tahun ya!
