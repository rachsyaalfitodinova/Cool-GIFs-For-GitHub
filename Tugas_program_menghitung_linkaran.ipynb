# %% [markdown]
# <a href="https://colab.research.google.com/github/rachsyaalfitodinova/Cool-GIFs-For-GitHub/blob/main/Tugas_program_menghitung_linkaran.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tugas menghitung luas lingkaran nama kelompok:doski misteri

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile keliling_lingkaran.cpp
# #include <iostream>
# using namespace std;
#
# int main()
# {
#     float r, luas;
#
#     cout << "program aplikasi menghitung keliling lingkaran" << endl;
#     cout << "masukan jari jari lingkaran" << endl;
#     cin >> r;
#
#     luas =2 * 3.14 * r;
#
#     cout << "keliling lingkaran = " << luas << endl;
#
#     return 0;
# }
# Out:
# Overwriting keliling_lingkaran.cpp

# %%
# !g++ keliling_lingkaran.cpp -o main

# %%
! ./main
# Out:
# program aplikasi menghitung keliling lingkaran
# masukan jari jari lingkaran
# 8
# keliling lingkaran = 50.24
